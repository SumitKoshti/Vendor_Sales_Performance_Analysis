# %% [markdown]
# **EXPLORATORY DATA ANALYSIS:**

# %%
# importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import mysql.connector

# %%
# creating connection engine
engine = create_engine("mysql+pymysql://root:pksumit100@localhost/inventorydb")

# %%
# List all tables in your database
tables = pd.read_sql_query(
    "SELECT table_name FROM information_schema.tables WHERE table_schema='inventorydb';",
    engine
)

print(tables)
# Out:
#                    TABLE_NAME
# 0             begin_inventory
# 1  clean_vendor_sales_summary
# 2               end_inventory
# 3             purchase_prices
# 4                   purchases
# 5                       sales
# 6              vendor_invoice
# 7        vendor_sales_summary

# %%
print(tables.columns)
# Out:
# Index(['TABLE_NAME'], dtype='object')

# %%
# printing all the tables
for table in tables["TABLE_NAME"]:
    print('-'*50, f'{table}', '-'*50)
    # print('Count of records:', pd.read_sql(f"select count(*) as count FROM {table}", engine)['count'].values[0])
    count_df = pd.read_sql(f"SELECT COUNT(*) as count FROM {table}", engine)
    print('Count of records:', count_df['count'].values[0])
    display(pd.read_sql(f"select * from  {table} limit 5", engine))
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of records: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- clean_vendor_sales_summary --------------------------------------------------
# ...

# %% [markdown]
# **CHECKING CONDITIONAL DATA:**

# %%
purchases = pd.read_sql("""select * from purchases where VendorNumber = 4466""", engine)
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchase_prices = pd.read_sql("""select * from purchase_prices where VendorNumber = 4466""", engine)
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice = pd.read_sql("""select * from vendor_invoice where VendorNumber = 4466""", engine)
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE      1/7/2024      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE     1/19/2024      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE     1/18/2024      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE     1/27/2024      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE      2/4/2024      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE      2/9/2024      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE     2/17/2024      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE      3/1/2024      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE      3/7/2024      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE     3/12/2024      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE     3/16/2024      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE     3/23/2024      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE     3/31/2024      9371
# ...

# %%
sales = pd.read_sql("""select * from sales where VendorNo = 4466""", engine)
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     9_BLACKPOOL_5215      9   5215  TGI Fridays Long Island Iced  1.75L
# 9449     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9452     9_BLACKPOOL_5255      9   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
purchases.groupby(["Brand", "PurchasePrice"])[["Quantity", "Dollars"]].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
sales.groupby("Brand")[["SalesDollars", "SalesPrice", "SalesQuantity"]].sum()
# Out:
#        SalesDollars  SalesPrice  SalesQuantity
# Brand
# 3140       50531.10    30071.85           3890
# 5215       60416.49    41542.02           4651
# 5255       79187.04    51180.60           6096

# %% [markdown]
# **Data Sources & Requirements:**
#
# * The purchases table stores actual purchase details such as purchase date, product/brand purchased from vendors, the dollar amount paid, and quantity purchased.
#
# * The purchase price column comes from the purchase_prices table, which holds actual and standard purchase prices per product. Each vendor–brand pair is unique in this table.
#
# * The vendor_invoice table summarizes purchase details, including quantity, total cost, and an extra column for freight. It ensures uniqueness by vendor and purchase order number.
#
# * The sales table records all sales transactions, capturing the brands purchased from vendors, quantities sold, selling price, and total revenue.
#
# Because the required data for analysis is spread across multiple tables, we need to build a summary table that consolidates:
#
# 1. Vendor purchase transactions
#
# 2. Sales transaction details
#
# 3. Freight costs per vendor
#
# 4. Actual product prices from vendors

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql("""SELECT VendorNumber, VendorName, SUM(Freight) as Freight_Cost
FROM vendor_invoice
GROUP BY VendorNumber""", engine)
freight_summary
# Out:
#      VendorNumber                   VendorName  Freight_Cost
# 0             105  ALTAMAR BRANDS LLC                  62.39
# 1            4466  AMERICAN VINTAGE BEVERAGE          793.91
# 2             388  ATLANTIC IMPORTING COMPANY         211.74
# 3             480  BACARDI USA INC                  89286.27
# 4             516  BANFI PRODUCTS CORP               8510.41
# ..            ...                          ...           ...
# 121        201359  FLAVOR ESSENCE INC                   0.09
# 122          4901  LAUREATE IMPORTS CO                  0.72
# 123         90059  BLACK COVE BEVERAGES                74.84
# 124          5083  LOYAL DOG WINERY                    10.68
# 125            54  AAPER ALCOHOL & CHEMICAL CO          0.48
#
# [126 rows x 3 columns]

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %% [markdown]
# **JOINING TABLES:**

# %%
pd.read_sql("""SELECT
p.VendorNumber,
p.VendorName,
p.Brand,
p.PurchasePrice,
pp.Volume,
pp.Price as ActualPrice,
SUM(p.Quantity) AS TotalPurchaseQuantity,
SUM(p.Dollars) AS TotalPurchaseDollars
FROM purchases p
INNER JOIN purchase_prices pp
ON p.Brand = pp.Brand
WHERE p.PurchasePrice > 0
GROUP BY p.VendorNumber, p.VendorName, p.Brand
ORDER BY TotalPurchaseDollars""", engine)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
sales_summary = pd.read_sql(""" SELECT
VendorNo,
Brand,
SUM(SalesDollars) as TotalSalesDollars,
SUM(SalesPrice) as TotalSalesPrice,
SUM(SalesQuantity) as TotalSalesQuantity,
SUM(ExciseTax) as TotalExciseTax
FROM sales
GROUP BY VendorNo, Brand
ORDER BY TotalSalesDollars""", engine)
sales_summary
# Out:
#        VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  \
# 0          8004   5287       9.800000e-01             0.98
# 1          9206   2773       9.900000e-01             0.99
# 2          3924   9123       1.980000e+00             0.99
# 3          3252   3933       1.980000e+00             0.99
# 4         10050   3623       1.980000e+00             1.98
# ...         ...    ...                ...              ...
# 11267      3960   3545       4.223108e+06        545778.28
# 11268      3960   4261       4.475973e+06        420050.01
# 11269     17035   8068       4.538121e+06        461140.15
# 11270      4425   3405       4.819073e+06        561512.37
# 11271      1128   1233       5.101920e+06        672819.31
#
#        TotalSalesQuantity  TotalExciseTax
# 0                     2.0            0.10
# 1                     1.0            0.05
# 2                     2.0            0.10
# 3                     2.0            0.10
# ...

# %% [markdown]
# **CREATING RESULTANT TABLE:**

# %%
import time
start = time.time()
vendor_sales_summary = pd.read_sql("""WITH FreightSummary AS(
    SELECT
        VendorNumber,
        SUM(Freight) as FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
),    

PurchaseSummary AS(
    SELECT
        p.VendorNumber,
        p.VendorName,
        p.Brand,
        p.Description,
        p.PurchasePrice,
        pp.Price AS ActualPrice,
        pp.Volume,
        SUM(p.Quantity) AS TotalPurchaseQuantity,
        SUM(p.Dollars) AS TotalPurchaseDollars
    FROM purchases p
    INNER JOIN purchase_prices pp
        ON p.Brand = pp.Brand
    WHERE p.PurchasePrice > 0
    GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
),
        
SalesSummary AS (
    SELECT
        VendorNo,
        Brand,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
)

SELECT
    ps.VendorNumber,
    ps.VendorName,
    ps.Brand,
    ps.Description,
    ps.PurchasePrice,
    ps.ActualPrice,
    ps.Volume,
    ps.TotalPurchaseQuantity,
    ps.TotalPurchaseDollars,
    ss.TotalSalesQuantity,
    ss.TotalSalesDollars,
    ss.TotalSalesPrice,
    ss.TotalExciseTax,
    fs.FreightCost
FROM PurchaseSummary ps
LEFT JOIN SalesSummary ss
    ON ps.VendorNumber = ss.VendorNo
    AND ps.Brand = ss.Brand
LEFT JOIN FreightSummary fs
    ON ps.VendorNumber = fs.VendorNumber
ORDER BY ps.TotalPurchaseDollars DESC""", engine)
end = time.time()

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  ActualPrice Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99   1750
# 1            Tito's Handmade Vodka          23.19        28.99   1750
# 2                 Absolut 80 Proof          18.24        24.99   1750
# ...

# %% [markdown]
# The above query produces a vendor-level sales and purchase summary, which is valuable for:
#
# **Performance Optimization:**
# * Reduced processing costs: It performs heavy joins and aggregations on large sales and purchase datasets only once.
#
# * Improved efficiency: Pre-aggregating data avoids repeated, expensive computations.
#
# * Better insights: Enables detailed analysis of sales, purchases, and vendor pricing patterns.
#
# * Faster reporting: Storing this data supports quick dashboarding and reporting.
#
# * Quicker data retrieval: Dashboards can pull summarized data directly from vendor_sales_summary instead of running complex queries repeatedly.

# %% [markdown]
# **DATA CLEANING:**

# %%
# checking null values
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       178
# TotalSalesDollars        178
# TotalSalesPrice          178
# TotalExciseTax           178
# FreightCost                0
# dtype: int64

# %%
vendor_sales_summary[vendor_sales_summary.isnull().any(axis=1)]
# Out:
#        VendorNumber                   VendorName  Brand  \
# 2456           9165  ULTRA BEVERAGE COMPANY LLP    1069
# 2528           9165  ULTRA BEVERAGE COMPANY LLP    1074
# 2982           9165  ULTRA BEVERAGE COMPANY LLP    3949
# 3007           9165  ULTRA BEVERAGE COMPANY LLP    1071
# 3026           9552  M S WALKER INC                2256
# ...             ...                          ...    ...
# 10628          9552  M S WALKER INC               24820
# 10634          5612  MILTONS DISTRIBUTING CO      23568
# 10638          3960  DIAGEO NORTH AMERICA INC      4397
# 10660          9815  WINE GROUP INC               13875
# 10672          5612  MILTONS DISTRIBUTING CO      17444
#
#                         Description  PurchasePrice  ActualPrice Volume  \
# 2456   Spade&Bushel 10yr Irish Wsky          29.84        39.99    375
# 2528            Brothership Whiskey          39.99        49.99    750
# 2982      Patron En Lalique Tequila        5681.81      7499.99    750
# ...

# %%
# replace null values with 0
vendor_sales_summary.fillna(0,inplace=True)

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Brand                    0
# Description              0
# PurchasePrice            0
# ActualPrice              0
# Volume                   0
# TotalPurchaseQuantity    0
# TotalPurchaseDollars     0
# TotalSalesQuantity       0
# TotalSalesDollars        0
# TotalSalesPrice          0
# TotalExciseTax           0
# FreightCost              0
# dtype: int64

# %%
# checking data types
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                    object
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %%
# checking categorical column data
vendor_sales_summary["VendorName"].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
vendor_sales_summary["Description"].unique()
# Out:
# array(['Jack Daniels No 7 Black', "Tito's Handmade Vodka",
#        'Absolut 80 Proof', ..., 'Crown Royal Apple',
#        'Concannon Glen Ellen Wh Zin', 'The Club Strawbry Margarita'],
#       dtype=object)

# %%
# removing white spaces
vendor_sales_summary["VendorName"] = vendor_sales_summary["VendorName"].str.strip()

# %%
vendor_sales_summary["VendorName"].unique()
# Out:
# array(['BROWN-FORMAN CORP', 'MARTIGNETTI COMPANIES', 'PERNOD RICARD USA',
#        'DIAGEO NORTH AMERICA INC', 'BACARDI USA INC',
#        'JIM BEAM BRANDS COMPANY', 'MAJESTIC FINE WINES',
#        'ULTRA BEVERAGE COMPANY LLP', 'STOLI GROUP,(USA) LLC',
#        'PROXIMO SPIRITS INC.', 'MOET HENNESSY USA INC', 'CAMPARI AMERICA',
#        'SAZERAC CO INC', 'CONSTELLATION BRANDS INC', 'M S WALKER INC',
#        'SAZERAC NORTH AMERICA INC.', 'PALM BAY INTERNATIONAL INC',
#        'REMY COINTREAU USA INC', 'SIDNEY FRANK IMPORTING CO',
#        'E & J GALLO WINERY', 'WILLIAM GRANT & SONS INC',
#        'HEAVEN HILL DISTILLERIES', 'DISARONNO INTERNATIONAL LLC',
#        'EDRINGTON AMERICAS', 'CASTLE BRANDS CORP.',
#        'SOUTHERN WINE & SPIRITS NE', 'STE MICHELLE WINE ESTATES',
#        'TRINCHERO FAMILY ESTATES', 'MHW LTD', 'WINE GROUP INC',
#        'PERFECTA WINES', 'LUXCO INC', 'TREASURY WINE ESTATES',
#        'DIAGEO CHATEAU ESTATE WINES', 'SHAW ROSS INT L IMP LTD',
# ...

# %%
# changing data type
vendor_sales_summary["Volume"] = vendor_sales_summary["Volume"].astype('float64')

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# ActualPrice              float64
# Volume                   float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesDollars        float64
# TotalSalesPrice          float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %% [markdown]
# **CREATING NEW COMPUTATIONAL COLUMNS:**

# %%
vendor_sales_summary["GrossProfit"] = vendor_sales_summary["TotalSalesDollars"] - vendor_sales_summary["TotalPurchaseDollars"]
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary["GrossProfit"].min()
# Out:
# -52002.78000000001

# %%
vendor_sales_summary["ProfitMargin"] = (vendor_sales_summary["GrossProfit"]/vendor_sales_summary["TotalSalesDollars"])*100
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary["StockTurnover"] = vendor_sales_summary["TotalSalesQuantity"]/vendor_sales_summary["TotalPurchaseQuantity"]
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary["SalesPurchaseRatio"]= vendor_sales_summary["TotalSalesDollars"]/vendor_sales_summary["TotalPurchaseDollars"]
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %% [markdown]
# **INSERTING DATA INTO TABLE:**

# %%
# Create a connection to your MySQL database
import pymysql


conn = pymysql.connect(
    host='localhost',   
    user='root',   
    password='pksumit100',
    database='inventorydb' 
)

# Create a cursor object
cursor = conn.cursor()

# %%
# Create a table in mysql
cursor.execute("""CREATE TABLE vendor_sales_summary
(
VendorNumber INT,
VendorName VARCHAR(100),
Brand INT,
Description VARCHAR(100),
PurchasePrice DECIMAL(10,2),
ActualPrice DECIMAL(10,2),
Volume DECIMAL(10,2),
TotalPurchaseQuantity INT,
TotalPurchaseDollars DECIMAL(15,2),
TotalSalesQuantity INT,
TotalSalesDollars DECIMAL(15,2),
TotalSalesPrice DECIMAL(15,2),
TotalExciseTax DECIMAL(15,2),
FreightCost DECIMAL(15,2),
GrossProfit DECIMAL(15,2),
ProfitMargin DECIMAL(15,2),
StockTurnover DECIMAL(15,2),
SalesPurchaseRatio DECIMAL(15,2),
PRIMARY KEY(VendorNumber, Brand)
);
""")
# Out:
# 0

# %%
pd.read_sql("SELECT * FROM vendor_sales_summary", engine)
# Out:
# Empty DataFrame
# Columns: [VendorNumber, VendorName, Brand, Description, PurchasePrice, ActualPrice, Volume, TotalPurchaseQuantity, TotalPurchaseDollars, TotalSalesQuantity, TotalSalesDollars, TotalSalesPrice, TotalExciseTax, FreightCost, GrossProfit, ProfitMargin, StockTurnover, SalesPurchaseRatio]
# Index: []

# %%
# checking inf values
numeric_df = vendor_sales_summary.select_dtypes(include=[np.number])

# Find inf/-inf rows
mask_inf = np.isinf(numeric_df)

rows_with_inf = vendor_sales_summary[mask_inf.any(axis=1)]

print(rows_with_inf)
# Out:
#        VendorNumber                  VendorName  Brand  \
# 2456           9165  ULTRA BEVERAGE COMPANY LLP   1069
# 2528           9165  ULTRA BEVERAGE COMPANY LLP   1074
# 2982           9165  ULTRA BEVERAGE COMPANY LLP   3949
# 3007           9165  ULTRA BEVERAGE COMPANY LLP   1071
# 3026           9552              M S WALKER INC   2256
# ...             ...                         ...    ...
# 10628          9552              M S WALKER INC  24820
# 10634          5612     MILTONS DISTRIBUTING CO  23568
# 10638          3960    DIAGEO NORTH AMERICA INC   4397
# 10660          9815              WINE GROUP INC  13875
# 10672          5612     MILTONS DISTRIBUTING CO  17444
#
#                         Description  PurchasePrice  ActualPrice  Volume  \
# 2456   Spade&Bushel 10yr Irish Wsky          29.84        39.99   375.0
# 2528            Brothership Whiskey          39.99        49.99   750.0
# 2982      Patron En Lalique Tequila        5681.81      7499.99   750.0
# ...

# %%
print(np.isinf(numeric_df).sum())
# Out:
# VendorNumber               0
# Brand                      0
# PurchasePrice              0
# ActualPrice                0
# Volume                     0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity         0
# TotalSalesDollars          0
# TotalSalesPrice            0
# TotalExciseTax             0
# FreightCost                0
# GrossProfit                0
# ProfitMargin             178
# StockTurnover              0
# SalesPurchaseRatio         0
# dtype: int64

# %%
# replace inf values with null values
vendor_sales_summary.replace([np.inf, -np.inf], np.nan, inplace=True)
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
vendor_sales_summary = vendor_sales_summary.round(3)
vendor_sales_summary
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  ActualPrice  Volume  \
# 0          Jack Daniels No 7 Black          26.27        36.99  1750.0
# 1            Tito's Handmade Vodka          23.19        28.99  1750.0
# 2                 Absolut 80 Proof          18.24        24.99  1750.0
# ...

# %%
# inserting data into table using chunksize method
vendor_sales_summary.to_sql(
    name='vendor_sales_summary',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 10692
