# %% [markdown]
# <h1 style="font-size:27px;">PROJECT : VENDOR PERFORMANCE ANALYSIS</h1>

# %% [markdown]
# **BUSINESS PROBLEM:**

# %% [markdown]
# Effective inventory and sales management are critical for optimizing profitability in the retail and wholesale industry.
# Companies need to ensure that they are not incurring losses due to inefficient pricing, poor inventory turnover, or vendor dependency. The goal of this analysis is to:
#
# * Identify underperformingbrands that require promotional or pricing adjustments.
# * Determine top vendors contributing to sales and gross profit
# * Analyse the impact of bulk purchasing on unit costs.
# * Assess inventory turnover to reduce holding costs and improve efficiency.
# * Investigate the profitability variance between high-performing and low-performing vendors.
#   dors.

# %% [markdown]
# **SCRIPT:**

# %%
# Whole script
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time
import logging

logging.basicConfig(
    filename= "logs/ingestion_db.log",
    level = logging.DEBUG,
    format= "%(asctime)s - %(levelname)s - %(message)s",
    filemode= "a"
)

# !pip install mysql-connector-python sqlalchemy pymysql
# !pip install pymysql sqlalchemy

engine = create_engine("mysql+pymysql://root:pksumit100@localhost")

with engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS inventoryDB;"))
    print("✅ Database 'inventoryDB' created")

def ingest_db(df, table_name, engine):
    ''' this function will ingest the dataframe into database table '''
    df.to_sql(
        table_name,
        con=engine,
        schema="inventoryDB",
        if_exists="replace",
        index=False
    )

def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir("Vendor_data"):
        df= pd.read_csv("Vendor_data/"+file)
        logging.info(f'Ingesting {file} in db')
        ingest_db(df, file[0:-4], engine)
    end = time.time()
    total_time = (end-start)/60
    logging.info("---------Ingestion Complete----------")
    logging.info(f'\nTotal Time Taken: {total_time} minutes')

if __name__ == '__main__':
    load_raw_data()
# Out:
# ...
# ✅ Database 'inventoryDB' created

# %%
# importing the libraries
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time
import logging

# adding the logging
logging.basicConfig(
    filename= "logs/ingestion_db.log",
    level = logging.DEBUG,
    format= "%(asctime)s - %(levelname)s - %(message)s",
    filemode= "a"
)

# installing the mysql connector
# !pip install mysql-connector-python sqlalchemy pymysql   

# creating engine
engine = create_engine("mysql+pymysql://root:pksumit100@localhost/inventorydb")

try:
    conn = engine.connect()
    print("✅ Connected to MySQL using PyMySQL + SQLAlchemy")
    conn.close()
except Exception as e:
    print("❌ Error:", e)
# Out:
# ...
# ✅ Connected to MySQL using PyMySQL + SQLAlchemy

# %%
from sqlalchemy import create_engine, text

# Connect to MySQL server (no database yet)
engine = create_engine("mysql+pymysql://root:pksumit100@localhost")

with engine.connect() as conn:
    conn.execute(text("CREATE DATABASE IF NOT EXISTS inventoryDB;"))
    print("✅ Database 'inventoryDB' created")
# Out:
# ✅ Database 'inventoryDB' created

# %%
for file in os.listdir("Vendor_data"):
    print(file)
# Out:
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# vendor_invoice.csv

# %%
def ingest_db(df, table_name, engine):
    ''' this function will ingest the dataframe into database table '''
    df.to_sql(
        table_name,
        con=engine,
        schema="inventoryDB",
        if_exists="replace",
        index=False
    )

# %%
for file in os.listdir("Vendor_data"):
    if '.csv' in file:
        df= pd.read_csv("Vendor_data/"+file)
        print(df.shape)
        ingest_db(df, file[0:-4], engine)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)

# %%
def load_raw_date():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start = time.time()
    for file in os.listdir("Vendor_data"):
        df= pd.read_csv("Vendor_data/"+file)
        logging.info(f'Ingesting {file} in db')
        ingest_db(df, file[0:-4], engine)
    end = time.time()
    total_time = (end-start)/60
    logging.info("---------Ingestion Complete----------")
    logging.info(f'\nTotal Time Taken: {total_time} minutes')
